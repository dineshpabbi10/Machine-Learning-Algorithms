# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from keras.preprocessing import image
# Out:
# Using TensorFlow backend.

# %%
img = image.load_img(r"C:\Users\dell\Pictures\Camera Roll\WIN_20181128_16_27_35_Pro.jpg",target_size=(100,130))

# %%
plt.imshow(img)

# %%
matrix =  image.img_to_array(img)

# %%
print(matrix.shape)
# Out:
# (100, 130, 3)

# %%
# Out:
# 159.0
