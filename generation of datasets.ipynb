# %%
import matplotlib.pyplot as pp
import pandas as pa
import numpy as np
from sklearn.datasets import load_digits

# %%
mnist = load_digits()
x = mnist.data
y = mnist.target
# print(x[:4,:])
# print(y[:4])
print(x.shape)
pp.subplot(221)
pp.imshow(x[5,:].reshape(8,8),cmap = "gray")
pp.show()
# Out:
# (1797, 64)

# %%
from sklearn.datasets import make_classification,make_regression,make_blobs,load_boston

# %%
x1,y1 = make_classification(n_samples=100,n_features=2,n_informative=2,n_redundant=0,n_classes=2)
print(x1.shape)
print(y1.shape)
# print(x1)
pp.figure(0,figsize=(20,20))
pp.subplot(221)
pp.scatter(x1[:,0],x1[:,1],c=y1,edgeColor='k')
pp.show()
# Out:
# (100, 2)
# (100,)
